# %% [markdown]
# ### Examples for loading data using the ImageOpener class
#
# **Note:** If you've made code changes to clearex, run the next cell to reload the module:

# %%
# OPTIONAL: Reload module to pick up code changes
# Only run this if you've edited the clearex source code
import importlib
import clearex.io.read
importlib.reload(clearex.io.read)
# Out:
# <module 'clearex.io.read' from '/project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/src/clearex/io/read.py'>

# %%
from clearex.io.read import ImageOpener

reader = ImageOpener()

# %%
# ND2 file example
nd2_path = "/archive/bioinformatics/Danuser_lab/Dean/Seweryn/SoRa/s_green_EEA1/1_non_expanded/full_large_8_sytox_EEA1_002.nd2"
data, info = reader.open(nd2_path)
print(f"ND2 pixel size: {info.pixel_size}")  # (0.9, 0.325, 0.325) µm
# Out:
# ND2 pixel size: (0.9, 0.325, 0.325)

# %%
# TIFF file example - extracts Z spacing from ImageDescription JSON
tiff_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2024-10-18-yuanyuan/38_100umrange_0.2umstep_Cell_004/CH00_000000.tiff"
data_tiff, info_tiff = reader.open(tiff_path)
print(f"TIFF pixel size: {info_tiff.pixel_size}")  # (0.2, 0.167, 0.167) µm
# Out:
# TIFF pixel size: (0.2, 0.1670001075060573, 0.1670001075060573)

# %%
n5_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2024-11-26-yuanyuan/fused.n5"
data_n5, info_n5 = reader.open(n5_path)
print(info_n5.pixel_size)
# Out:
# /project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/.venv/lib/python3.13/site-packages/zarr/n5.py:77: FutureWarning: The N5Store is deprecated and will be removed in a Zarr-Python version 3, see https://github.com/zarr-developers/zarr-python/issues/1274 for more information.
#   super().__init__(*args, **kwargs)
# /project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/.venv/lib/python3.13/site-packages/zarr/storage.py:179: FutureWarning: The N5Store is deprecated and will be removed in a Zarr-Python version 3, see https://github.com/zarr-developers/zarr-python/issues/1274 and https://github.com/zarr-developers/n5py for more information.
#   return N5Store(store)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 n5_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2024-11-26-yuanyuan/fused.n5"
# ----> 2 data_n5, info_n5 = reader.open(n5_path)
#       3 print(info_n5.pixel_size)
#
# File /project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/src/clearex/io/read.py:1683, in ImageOpener.open(self, path, prefer_dask, chunks, **kwargs)
#    1680         continue
#    1682 logger.error(msg=f"No suitable reader found for {p}")
# -> 1683 raise ValueError("No suitable reader found for:", p)
#
# ValueError: ('No suitable reader found for:', PosixPath('/archive/bioinformatics/Danuser_lab/Dean/dean/2024-11-26-yuanyuan/fused.n5'))

# %%
h5_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2023-11-13-Nicole/488myosin_561nuclear_647rfp/2023-11-08/Cell_001/CH00_000000.h5"
data_h5, info_h5 = reader.open(h5_path)
info_h5.pixel_size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 h5_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2023-11-13-Nicole/488myosin_561nuclear_647rfp/2023-11-08/Cell_001/CH00_000000.h5"
# ----> 2 data_h5, info_h5 = reader.open(h5_path)
#       3 info_h5.pixel_size
#
# File /project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/src/clearex/io/read.py:1621, in ImageOpener.open(self, path, prefer_dask, chunks, **kwargs)
#    1618         continue
#    1620 logger.error(msg=f"No suitable reader found for {p}")
# -> 1621 raise ValueError("No suitable reader found for:", p)
#
# ValueError: ('No suitable reader found for:', PosixPath('/archive/bioinformatics/Danuser_lab/Dean/dean/2023-11-13-Nicole/488myosin_561nuclear_647rfp/2023-11-08/Cell_001/CH00_000000.h5'))

# %%
zarr_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2024-05-21-tiling/cell5_fused_tp_0_ch_0.zarr"
data_zarr, info_zarr = reader.open(zarr_path)
info_zarr.pixel_size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 zarr_path = "/archive/bioinformatics/Danuser_lab/Dean/dean/2024-05-21-tiling/cell5_fused_tp_0_ch_0.zarr"
# ----> 2 data_zarr, info_zarr = reader.open(zarr_path)
#       3 info_zarr.pixel_size
#
# File /project/bioinformatics/Danuser_lab/Dean/dean/git/clearex/src/clearex/io/read.py:1621, in ImageOpener.open(self, path, prefer_dask, chunks, **kwargs)
#    1618         continue
#    1620 logger.error(msg=f"No suitable reader found for {p}")
# -> 1621 raise ValueError("No suitable reader found for:", p)
#
# ValueError: ('No suitable reader found for:', PosixPath('/archive/bioinformatics/Danuser_lab/Dean/dean/2024-05-21-tiling/cell5_fused_tp_0_ch_0.zarr'))
